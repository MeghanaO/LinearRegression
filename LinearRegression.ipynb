# %%
# imports
import pandas as pd
import numpy as np
import math
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
import statsmodels.formula.api as smf
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#loading input csv file
dataW = pd.read_csv('../winequality-white.csv',header=0,sep=';')

dataW.shape
type(dataW)
dataW.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
dataW.rename(columns={'fixed acidity': 'fixed_acidity','citric acid':'citric_acid','volatile acidity':'volatile_acidity','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide','chlorides':'chlorides','density':'density','pH':'pH','sulphates':'sulphates','alcohol':'alcohol'}, inplace=True)

# %%
WhiteList = dataW.columns.tolist();
len(WhiteList)
WhiteList[1]
# Out:
# 'volatile_acidity'

# %%
print('----------------------------------------------------------------')
White1= smf.ols(formula='quality ~ fixed_acidity', data=dataW).fit()
print('Parameters : ',White1.params)
print('AIC : ',White1.aic)
print('Rsquare : ',White1.rsquared)
print('p values : ',White1.pvalues)
print('----------------------------------------------------------------')
White2 = smf.ols(formula='quality ~ volatile_acidity', data=dataW).fit()
print('Parameters : ',White2.params)
print('AIC : ',White2.aic)
print('Rsquare : ',White2.rsquared)
print('p values : ',White2.pvalues)
print('----------------------------------------------------------------')
White3 = smf.ols(formula='quality ~ citric_acid', data=dataW).fit()
print('Parameters : ',White3.params)
print('AIC : ',White3.aic)
print('Rsquare : ',White3.rsquared)
print('p values : ',White3.pvalues)
print('----------------------------------------------------------------')
White4 = smf.ols(formula='quality ~ residual_sugar', data=dataW).fit()
print('Parameters : ',White4.params)
print('AIC : ',White4.aic)
print('Rsquare : ',White4.rsquared)
print('p values : ',White4.pvalues)
print('----------------------------------------------------------------')
White5 = smf.ols(formula='quality ~ chlorides', data=dataW).fit()
print('Parameters : ',White5.params)
print('AIC : ',White5.aic)
print('Rsquare : ',White5.rsquared)
print('p values : ',White5.pvalues)
print('----------------------------------------------------------------')
White6 = smf.ols(formula='quality ~ free_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White6.params)
print('AIC : ',White6.aic)
print('Rsquare : ',White6.rsquared)
print('p values : ',White6.pvalues)
print('----------------------------------------------------------------')
White7 = smf.ols(formula='quality ~ total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White7.params)
print('AIC : ',White7.aic)
print('Rsquare : ',White7.rsquared)
print('p values : ',White7.pvalues)
print('----------------------------------------------------------------')
White8 = smf.ols(formula='quality ~ density', data=dataW).fit()
print('Parameters : ',White8.params)
print('AIC : ',White8.aic)
print('Rsquare : ',White8.rsquared)
print('p values : ',White8.pvalues)
print('----------------------------------------------------------------')
White9 = smf.ols(formula='quality ~ pH', data=dataW).fit()
print('Parameters : ',White9.params)
print('AIC : ',White9.aic)
print('Rsquare : ',White9.rsquared)
print('p values : ',White9.pvalues)
print('----------------------------------------------------------------')
White10 = smf.ols(formula='quality ~ sulphates', data=dataW).fit()
print('Parameters : ',White10.params)
print('AIC : ',White10.aic)
print('Rsquare : ',White10.rsquared)
print('p values : ',White10.pvalues)
print('----------------------------------------------------------------')
White11 = smf.ols(formula='quality ~ alcohol', data=dataW).fit()
print('Parameters : ',White11.params)
print('AIC : ',White11.aic)
print('Rsquare : ',White11.rsquared)
print('p values : ',White11.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept        6.695610
# fixed_acidity   -0.119289
# dtype: float64
# AIC :  12649.542674671115
# Rsquare :  0.012919239085696144
# p values :  Intercept        0.000000e+00
# fixed_acidity    1.479886e-15
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept           6.353965
# volatile_acidity   -1.710947
# dtype: float64
# AIC :  12523.903238229133
# Rsquare :  0.03791703462546103
# p values :  Intercept           0.000000e+00
# volatile_acidity    4.673261e-43
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept      5.900432
# citric_acid   -0.067393
# dtype: float64
# AIC :  12712.818013276958
# Rsquare :  8.480735490934421e-05
# p values :  Intercept      0.000000
# citric_acid    0.519346
# dtype: float64
# ----------------------------------------------------------------
# ...

# %%
print('----------------------------------------------------------------')
White11= smf.ols(formula='quality ~ alcohol + volatile_acidity', data=dataW).fit()
print('Parameters : ',White11.params)
print('AIC : ',White11.aic)
print('Rsquare : ',White11.rsquared)
print('p values : ',White11.pvalues)
print('----------------------------------------------------------------')
White12= smf.ols(formula='quality ~ alcohol + citric_acid', data=dataW).fit()
print('Parameters : ',White12.params)
print('AIC : ',White12.aic)
print('Rsquare : ',White12.rsquared)
print('p values : ',White12.pvalues)
print('----------------------------------------------------------------')
White13= smf.ols(formula='quality ~ alcohol + residual_sugar', data=dataW).fit()
print('Parameters : ',White13.params)
print('AIC : ',White13.aic)
print('Rsquare : ',White13.rsquared)
print('p values : ',White13.pvalues)
print('----------------------------------------------------------------')
White14= smf.ols(formula='quality ~ alcohol + chlorides', data=dataW).fit()
print('Parameters : ',White14.params)
print('AIC : ',White14.aic)
print('Rsquare : ',White14.rsquared)
print('p values : ',White14.pvalues)
print('----------------------------------------------------------------')
White15= smf.ols(formula='quality ~ alcohol + free_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White15.params)
print('AIC : ',White15.aic)
print('Rsquare : ',White15.rsquared)
print('p values : ',White15.pvalues)
print('----------------------------------------------------------------')
White16= smf.ols(formula='quality ~ alcohol + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White16.params)
print('AIC : ',White16.aic)
print('Rsquare : ',White16.rsquared)
print('p values : ',White16.pvalues)
print('----------------------------------------------------------------')
White17= smf.ols(formula='quality ~ alcohol + density', data=dataW).fit()
print('Parameters : ',White17.params)
print('AIC : ',White17.aic)
print('Rsquare : ',White17.rsquared)
print('p values : ',White17.pvalues)
print('----------------------------------------------------------------')
White18= smf.ols(formula='quality ~ alcohol + pH', data=dataW).fit()
print('Parameters : ',White18.params)
print('AIC : ',White18.aic)
print('Rsquare : ',White18.rsquared)
print('p values : ',White18.pvalues)
print('----------------------------------------------------------------')
White19= smf.ols(formula='quality ~ alcohol + sulphates', data=dataW).fit()
print('Parameters : ',White19.params)
print('AIC : ',White19.aic)
print('Rsquare : ',White19.rsquared)
print('p values : ',White19.pvalues)
print('----------------------------------------------------------------')
White110= smf.ols(formula='quality ~ fixed_acidity + alcohol', data=dataW).fit()
print('Parameters : ',White110.params)
print('AIC : ',White110.aic)
print('Rsquare : ',White110.rsquared)
print('p values : ',White110.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept           3.017282
# alcohol             0.324447
# volatile_acidity   -1.979194
# dtype: float64
# AIC :  11369.551595515226
# Rsquare :  0.24023118475336191
# p values :  Intercept           1.136063e-190
# alcohol             2.821825e-253
# volatile_acidity     1.773318e-70
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept      2.509822
# alcohol        0.314773
# citric_acid    0.175003
# dtype: float64
# AIC :  11681.344222676827
# Rsquare :  0.19029391204459833
# p values :  Intercept      1.317880e-118
# alcohol        1.375632e-226
# citric_acid     6.380023e-02
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept         2.021445
# alcohol           0.353637
# residual_sugar    0.021627
# dtype: float64
# AIC :  11610.316711315549
# Rsquare :  0.2019510008159675
# ...

# %%
print('----------------------------------------------------------------')
White21= smf.ols(formula='quality ~ alcohol + volatile_acidity + fixed_acidity', data=dataW).fit()
print('Parameters : ',White21.params)
print('AIC : ',White21.aic)
print('Rsquare : ',White21.rsquared)
print('p values : ',White21.pvalues)
print('----------------------------------------------------------------')
White22= smf.ols(formula='quality ~ alcohol + volatile_acidity + citric_acid', data=dataW).fit()
print('Parameters : ',White22.params)
print('AIC : ',White22.aic)
print('Rsquare : ',White22.rsquared)
print('p values : ',White22.pvalues)
print('----------------------------------------------------------------')
White23= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar', data=dataW).fit()
print('Parameters : ',White23.params)
print('AIC : ',White23.aic)
print('Rsquare : ',White23.rsquared)
print('p values : ',White23.pvalues)
print('----------------------------------------------------------------')
White24= smf.ols(formula='quality ~ alcohol + volatile_acidity + chlorides', data=dataW).fit()
print('Parameters : ',White24.params)
print('AIC : ',White24.aic)
print('Rsquare : ',White24.rsquared)
print('p values : ',White24.pvalues)
print('----------------------------------------------------------------')
White25= smf.ols(formula='quality ~ alcohol + volatile_acidity + free_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White25.params)
print('AIC : ',White25.aic)
print('Rsquare : ',White25.rsquared)
print('p values : ',White25.pvalues)
print('----------------------------------------------------------------')
White26= smf.ols(formula='quality ~ alcohol + volatile_acidity + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White26.params)
print('AIC : ',White26.aic)
print('Rsquare : ',White26.rsquared)
print('p values : ',White26.pvalues)
print('----------------------------------------------------------------')
White27= smf.ols(formula='quality ~ alcohol + volatile_acidity + density', data=dataW).fit()
print('Parameters : ',White27.params)
print('AIC : ',White27.aic)
print('Rsquare : ',White27.rsquared)
print('p values : ',White27.pvalues)
print('----------------------------------------------------------------')
White28= smf.ols(formula='quality ~ alcohol + volatile_acidity + pH', data=dataW).fit()
print('Parameters : ',White28.params)
print('AIC : ',White28.aic)
print('Rsquare : ',White28.rsquared)
print('p values : ',White28.pvalues)
print('----------------------------------------------------------------')
White29= smf.ols(formula='quality ~ alcohol + volatile_acidity + sulphates', data=dataW).fit()
print('Parameters : ',White29.params)
print('AIC : ',White29.aic)
print('Rsquare : ',White29.rsquared)
print('p values : ',White29.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept           3.548185
# alcohol             0.318817
# volatile_acidity   -1.987552
# fixed_acidity      -0.068476
# dtype: float64
# AIC :  11344.439663086534
# Rsquare :  0.24442512013197892
# p values :  Intercept           2.676956e-131
# alcohol             1.411441e-243
# volatile_acidity     2.205120e-71
# fixed_acidity        1.944990e-07
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept           3.046895
# alcohol             0.324021
# volatile_acidity   -1.990632
# citric_acid        -0.065692
# dtype: float64
# AIC :  11371.045945311831
# Rsquare :  0.24030961624094327
# p values :  Intercept           8.596211e-167
# alcohol             1.130434e-251
# volatile_acidity     7.962173e-70
# citric_acid          4.772304e-01
# dtype: float64
# ----------------------------------------------------------------
# ...

# %%
print('----------------------------------------------------------------')
White31= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + fixed_acidity', data=dataW).fit()
print('Parameters : ',White31.params)
print('AIC : ',White31.aic)
print('Rsquare : ',White31.rsquared)
print('p values : ',White31.pvalues)
print('----------------------------------------------------------------')
White32= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + citric_acid', data=dataW).fit()
print('Parameters : ',White32.params)
print('AIC : ',White32.aic)
print('Rsquare : ',White32.rsquared)
print('p values : ',White32.pvalues)
print('----------------------------------------------------------------')
White33= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + chlorides', data=dataW).fit()
print('Parameters : ',White33.params)
print('AIC : ',White33.aic)
print('Rsquare : ',White33.rsquared)
print('p values : ',White33.pvalues)
print('----------------------------------------------------------------')
White34= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White34.params)
print('AIC : ',White34.aic)
print('Rsquare : ',White34.rsquared)
print('p values : ',White34.pvalues)
print('----------------------------------------------------------------')
White35= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White35.params)
print('AIC : ',White35.aic)
print('Rsquare : ',White35.rsquared)
print('p values : ',White35.pvalues)
print('----------------------------------------------------------------')
White36= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + density', data=dataW).fit()
print('Parameters : ',White36.params)
print('AIC : ',White36.aic)
print('Rsquare : ',White36.rsquared)
print('p values : ',White36.pvalues)
print('----------------------------------------------------------------')
White37= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + pH', data=dataW).fit()
print('Parameters : ',White37.params)
print('AIC : ',White37.aic)
print('Rsquare : ',White37.rsquared)
print('p values : ',White37.pvalues)
print('----------------------------------------------------------------')
White38= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + sulphates', data=dataW).fit()
print('Parameters : ',White38.params)
print('AIC : ',White38.aic)
print('Rsquare : ',White38.rsquared)
print('p values : ',White38.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept           2.918716
# alcohol             0.369516
# volatile_acidity   -2.118500
# residual_sugar      0.027172
# fixed_acidity      -0.074432
# dtype: float64
# AIC :  11221.377758096505
# Rsquare :  0.2634731950347856
# p values :  Intercept            4.012575e-81
# alcohol             2.227632e-264
# volatile_acidity     1.487666e-81
# residual_sugar       5.294840e-29
# fixed_acidity        1.047181e-08
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept           2.415490
# alcohol             0.374228
# volatile_acidity   -2.134684
# residual_sugar      0.026946
# citric_acid        -0.151358
# dtype: float64
# AIC :  11251.434602573947
# Rsquare :  0.25893956185797906
# p values :  Intercept            2.980062e-87
# alcohol             1.265515e-270
# volatile_acidity     1.864721e-80
# residual_sugar       3.007963e-28
# ...

# %%
print('----------------------------------------------------------------')
White41= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + fixed_acidity', data=dataW).fit()
print('Parameters : ',White41.params)
print('AIC : ',White41.aic)
print('Rsquare : ',White41.rsquared)
print('p values : ',White41.pvalues)
print('----------------------------------------------------------------')
White42= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + citric_acid', data=dataW).fit()
print('Parameters : ',White42.params)
print('AIC : ',White42.aic)
print('Rsquare : ',White42.rsquared)
print('p values : ',White42.pvalues)
print('----------------------------------------------------------------')
White43= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + chlorides', data=dataW).fit()
print('Parameters : ',White43.params)
print('AIC : ',White43.aic)
print('Rsquare : ',White43.rsquared)
print('p values : ',White43.pvalues)
print('----------------------------------------------------------------')
White44= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White44.params)
print('AIC : ',White44.aic)
print('Rsquare : ',White44.rsquared)
print('p values : ',White44.pvalues)
print('----------------------------------------------------------------')
White45= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density', data=dataW).fit()
print('Parameters : ',White45.params)
print('AIC : ',White45.aic)
print('Rsquare : ',White45.rsquared)
print('p values : ',White45.pvalues)
print('----------------------------------------------------------------')
White46= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + pH', data=dataW).fit()
print('Parameters : ',White46.params)
print('AIC : ',White46.aic)
print('Rsquare : ',White46.rsquared)
print('p values : ',White46.pvalues)
print('----------------------------------------------------------------')
White47= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + sulphates', data=dataW).fit()
print('Parameters : ',White47.params)
print('AIC : ',White47.aic)
print('Rsquare : ',White47.rsquared)
print('p values : ',White47.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept              2.663225
# alcohol                0.376845
# volatile_acidity      -2.051540
# residual_sugar         0.024017
# free_sulfur_dioxide    0.003757
# fixed_acidity         -0.067530
# dtype: float64
# AIC :  11192.989068552952
# Rsquare :  0.268028686080204
# p values :  Intercept               5.598967e-63
# alcohol                7.239430e-271
# volatile_acidity        2.665311e-76
# residual_sugar          4.611582e-22
# free_sulfur_dioxide     3.610115e-08
# fixed_acidity           2.157222e-07
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept              2.201120
# alcohol                0.381766
# volatile_acidity      -2.066782
# residual_sugar         0.023570
# free_sulfur_dioxide    0.004163
# citric_acid           -0.178806
# dtype: float64
# AIC :  11216.079980287457
# Rsquare :  0.26456976643376817
# ...

# %%
print('----------------------------------------------------------------')
White51= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + fixed_acidity', data=dataW).fit()
print('Parameters : ',White51.params)
print('AIC : ',White51.aic)
print('Rsquare : ',White51.rsquared)
print('p values : ',White51.pvalues)
print('----------------------------------------------------------------')
White52= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + citric_acid', data=dataW).fit()
print('Parameters : ',White52.params)
print('AIC : ',White52.aic)
print('Rsquare : ',White52.rsquared)
print('p values : ',White52.pvalues)
print('----------------------------------------------------------------')
White53= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + chlorides', data=dataW).fit()
print('Parameters : ',White53.params)
print('AIC : ',White53.aic)
print('Rsquare : ',White53.rsquared)
print('p values : ',White53.pvalues)
print('----------------------------------------------------------------')
White54= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White54.params)
print('AIC : ',White54.aic)
print('Rsquare : ',White54.rsquared)
print('p values : ',White54.pvalues)
print('----------------------------------------------------------------')
White55= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH', data=dataW).fit()
print('Parameters : ',White55.params)
print('AIC : ',White55.aic)
print('Rsquare : ',White55.rsquared)
print('p values : ',White55.pvalues)
print('----------------------------------------------------------------')
White56= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + sulphates', data=dataW).fit()
print('Parameters : ',White56.params)
print('AIC : ',White56.aic)
print('Rsquare : ',White56.rsquared)
print('p values : ',White56.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept              52.887789
# alcohol                 0.316821
# volatile_acidity       -2.013794
# residual_sugar          0.041830
# free_sulfur_dioxide     0.003768
# density               -50.204599
# fixed_acidity          -0.040316
# dtype: float64
# AIC :  11181.541292575506
# Rsquare :  0.2700356043698774
# p values :  Intercept              1.142823e-04
# alcohol                1.413267e-59
# volatile_acidity       3.091996e-73
# residual_sugar         1.988689e-14
# free_sulfur_dioxide    3.170409e-08
# density                2.480040e-04
# fixed_acidity          7.061372e-03
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept              68.954283
# alcohol                 0.299661
# volatile_acidity       -2.008144
# residual_sugar          0.047391
# free_sulfur_dioxide     0.003960
# density               -66.481220
# ...

# %%
print('----------------------------------------------------------------')
White61= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + fixed_acidity', data=dataW).fit()
print('Parameters : ',White61.params)
print('AIC : ',White61.aic)
print('Rsquare : ',White61.rsquared)
print('p values : ',White61.pvalues)
print('----------------------------------------------------------------')
White62= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + citric_acid', data=dataW).fit()
print('Parameters : ',White62.params)
print('AIC : ',White62.aic)
print('Rsquare : ',White62.rsquared)
print('p values : ',White62.pvalues)
print('----------------------------------------------------------------')
White63= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + chlorides', data=dataW).fit()
print('Parameters : ',White63.params)
print('AIC : ',White63.aic)
print('Rsquare : ',White63.rsquared)
print('p values : ',White63.pvalues)
print('----------------------------------------------------------------')
White64= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White64.params)
print('AIC : ',White64.aic)
print('Rsquare : ',White64.rsquared)
print('p values : ',White64.pvalues)
print('----------------------------------------------------------------')
White65= smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates', data=dataW).fit()
print('Parameters : ',White65.params)
print('AIC : ',White65.aic)
print('Rsquare : ',White65.rsquared)
print('p values : ',White65.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept              120.929672
# alcohol                  0.231929
# volatile_acidity        -1.932440
# residual_sugar           0.069937
# free_sulfur_dioxide      0.003631
# density               -120.648814
# pH                       0.654264
# fixed_acidity            0.045867
# dtype: float64
# AIC :  11143.7255759535
# Rsquare :  0.27594541337001144
# p values :  Intercept              3.927457e-12
# alcohol                5.429903e-23
# volatile_acidity       2.234638e-67
# residual_sugar         3.635969e-23
# free_sulfur_dioxide    8.821453e-08
# density                8.345577e-12
# pH                     2.891401e-10
# fixed_acidity          2.322234e-02
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept              95.218996
# alcohol                 0.262126
# volatile_acidity       -1.953187
# residual_sugar          0.060001
# ...

# %%
print('----------------------------------------------------------------')
White71 = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + fixed_acidity', data=dataW).fit()
print('Parameters : ',White71.params)
print('AIC : ',White71.aic)
print('Rsquare : ',White71.rsquared)
print('p values : ',White71.pvalues)
print('----------------------------------------------------------------')
White72 = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + citric_acid', data=dataW).fit()
print('Parameters : ',White72.params)
print('AIC : ',White72.aic)
print('Rsquare : ',White72.rsquared)
print('p values : ',White72.pvalues)
print('----------------------------------------------------------------')
White73 = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + chlorides', data=dataW).fit()
print('Parameters : ',White73.params)
print('AIC : ',White73.aic)
print('Rsquare : ',White73.rsquared)
print('p values : ',White73.pvalues)
print('----------------------------------------------------------------')
White74 = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White74.params)
print('AIC : ',White74.aic)
print('Rsquare : ',White74.rsquared)
print('p values : ',White74.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept              154.106249
# alcohol                  0.193163
# volatile_acidity        -1.888140
# residual_sugar           0.082847
# free_sulfur_dioxide      0.003349
# density               -154.291277
# pH                       0.694213
# sulphates                0.628508
# fixed_acidity            0.068104
# dtype: float64
# AIC :  11106.287753625907
# Rsquare :  0.2817519637249497
# p values :  Intercept              2.206827e-17
# alcohol                1.306643e-15
# volatile_acidity       1.020239e-64
# residual_sugar         1.391738e-29
# free_sulfur_dioxide    7.673309e-07
# density                5.275581e-17
# pH                     2.066280e-11
# sulphates              3.522028e-10
# fixed_acidity          8.643880e-04
# dtype: float64
# ----------------------------------------------------------------
# Parameters :  Intercept              112.715128
# ...

# %%
print('----------------------------------------------------------------')
White81 = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + fixed_acidity + citric_acid', data=dataW).fit()
print('Parameters : ',White81.params)
print('AIC : ',White81.aic)
print('Rsquare : ',White81.rsquared)
print('p values : ',White81.pvalues)
print('----------------------------------------------------------------')
White82 = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + fixed_acidity + chlorides', data=dataW).fit()
print('Parameters : ',White82.params)
print('AIC : ',White82.aic)
print('Rsquare : ',White82.rsquared)
print('p values : ',White82.pvalues)
print('----------------------------------------------------------------')
White83 = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + fixed_acidity + total_sulfur_dioxide', data=dataW).fit()
print('Parameters : ',White83.params)
print('AIC : ',White83.aic)
print('Rsquare : ',White83.rsquared)
print('p values : ',White83.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept              154.371746
# alcohol                  0.192812
# volatile_acidity        -1.885455
# residual_sugar           0.082930
# free_sulfur_dioxide      0.003341
# density               -154.563148
# pH                       0.695837
# sulphates                0.627899
# fixed_acidity            0.067777
# citric_acid              0.014425
# dtype: float64
# AIC :  11108.26471159611
# Rsquare :  0.28175534262526103
# p values :  Intercept              2.747290e-17
# alcohol                1.982321e-15
# volatile_acidity       5.590681e-63
# residual_sugar         1.766880e-29
# free_sulfur_dioxide    8.889140e-07
# density                6.560519e-17
# pH                     2.379692e-11
# sulphates              3.797301e-10
# fixed_acidity          9.783318e-04
# citric_acid            8.794762e-01
# dtype: float64
# ----------------------------------------------------------------
# ...

# %%
print('----------------------------------------------------------------')
WhiteBest = smf.ols(formula='quality ~ alcohol + volatile_acidity + residual_sugar + free_sulfur_dioxide + density + pH + sulphates + fixed_acidity', data=dataW).fit()
print('Parameters : ',White71.params)
print('AIC : ',White71.aic)
print('Rsquare : ',White71.rsquared)
print('p values : ',White71.pvalues)
# Out:
# ----------------------------------------------------------------
# Parameters :  Intercept              154.106249
# alcohol                  0.193163
# volatile_acidity        -1.888140
# residual_sugar           0.082847
# free_sulfur_dioxide      0.003349
# density               -154.291277
# pH                       0.694213
# sulphates                0.628508
# fixed_acidity            0.068104
# dtype: float64
# AIC :  11106.287753625907
# Rsquare :  0.2817519637249497
# p values :  Intercept              2.206827e-17
# alcohol                1.306643e-15
# volatile_acidity       1.020239e-64
# residual_sugar         1.391738e-29
# free_sulfur_dioxide    7.673309e-07
# density                5.275581e-17
# pH                     2.066280e-11
# sulphates              3.522028e-10
# fixed_acidity          8.643880e-04
# dtype: float64

# %%
Y_Pred = WhiteBest.predict().tolist();
Y_Pred
# Out:
# [5.558555534699668,
#  5.216694061832502,
#  5.756701886569717,
#  5.78979075363142,
#  5.78979075363142,
#  5.756701886569717,
#  5.457658547531889,
#  5.558555534699668,
#  5.216694061832502,
#  5.768858893681822,
#  6.178879646008438,
#  5.5756476474090855,
#  6.090176032242376,
#  6.784700806274504,
#  5.6520120524861515,
#  6.292351402459639,
#  4.970096350048392,
#  5.8832603085473725,
#  5.787451031117681,
#  5.486523552268608,
#  5.8832603085473725,
#  5.872590391304724,
#  5.884165047882483,
#  4.48184326954782,
#  5.273209752647404,
#  6.026486048249275,
#  5.715045110373142,
#  5.900455796598655,
#  6.047311698596017,
#  6.415266245901095,
#  5.756670970948736,
#  5.8793769504957325,
#  5.93213520988165,
#  5.6533091957463775,
#  6.141036177466017,
#  6.4113862171962985,
#  5.4715530948210445,
#  5.857924144699095,
#  5.628107968860503,
#  5.628107968860503,
#  5.428134234916069,
#  5.422879429035552,
#  5.477955128391201,
#  5.47850877294269,
#  5.518084840538378,
# ...

# %%
len(Y_Pred)
# Out:
# 4898

# %%
len(dataW.quality)
# Out:
# 4898

# %%
Y_actual = dataW.quality.tolist()
Y_actual
# Out:
# [6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  5,
#  5,
#  5,
#  7,
#  5,
#  7,
#  6,
#  8,
#  6,
#  5,
#  8,
#  7,
#  8,
#  5,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  6,
#  6,
#  6,
#  6,
#  5,
#  5,
#  5,
#  6,
#  5,
#  5,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  4,
#  5,
#  6,
#  5,
#  6,
#  7,
#  7,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  5,
#  6,
#  6,
#  5,
#  7,
#  5,
#  8,
#  5,
#  6,
#  5,
#  5,
#  6,
#  8,
#  5,
#  7,
#  7,
#  5,
#  5,
#  6,
#  6,
#  5,
#  6,
#  5,
#  6,
#  6,
#  6,
#  5,
#  6,
#  6,
#  5,
#  7,
#  7,
#  7,
#  6,
#  6,
#  7,
#  4,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  6,
#  5,
#  6,
#  6,
#  5,
#  6,
#  5,
#  5,
#  5,
#  5,
#  4,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  6,
#  5,
#  7,
#  7,
#  6,
#  5,
#  7,
#  5,
#  5,
#  5,
#  5,
#  6,
#  5,
#  7,
#  6,
#  5,
#  5,
#  6,
#  6,
#  6,
#  6,
#  6,
#  4,
#  7,
#  6,
#  7,
#  6,
#  6,
#  5,
#  6,
#  6,
#  6,
#  7,
#  8,
#  8,
#  7,
#  5,
#  5,
#  6,
#  5,
#  5,
# ...

# %%
SSE = [0]*4898;
index = [0]*4898;
for i in range(len(Y_actual)-1) :
    #print(i)
    index[i] = i+1;
    SSE[i] = abs(Y_actual[i]-Y_Pred[i]);
    #dic = {(k,v) for (k,v) in i SSE[i]}
    
len(SSE)
#dic = {i:True for i in SSE}
d = dict(zip(index,SSE))
SSE
# Out:
# [0.4414444653003322,
#  0.7833059381674978,
#  0.24329811343028318,
#  0.21020924636857963,
#  0.21020924636857963,
#  0.24329811343028318,
#  0.5423414524681114,
#  0.4414444653003322,
#  0.7833059381674978,
#  0.2311411063181783,
#  1.178879646008438,
#  0.5756476474090855,
#  1.0901760322423764,
#  0.215299193725496,
#  0.6520120524861515,
#  0.707648597540361,
#  1.029903649951608,
#  2.1167396914526275,
#  0.21254896888231922,
#  0.4865235522686078,
#  2.1167396914526275,
#  1.1274096086952756,
#  2.115834952117517,
#  0.5181567304521799,
#  0.7267902473525956,
#  0.02648604824927503,
#  0.28495488962685833,
#  0.0995442034013454,
#  0.04731169859601714,
#  0.584733754098905,
#  0.24332902905126375,
#  0.1206230495042675,
#  0.06786479011834956,
#  0.34669080425362253,
#  1.1410361774660167,
#  1.4113862171962985,
#  0.47155309482104446,
#  0.14207585530090494,
#  0.6281079688605029,
#  0.6281079688605029,
#  0.5718657650839312,
#  0.577120570964448,
#  0.5220448716087986,
# ...

# %%
s = sorted(d.items(), key=lambda x: (-x[1], x[0]))
print(s)
outlierLines = [0]*5; 
for i in range(5) :
    outlierLines[i] = s[i][0];
outlierLines
for i in range(len(outlierLines)) :
    print(dataW.loc[outlierLines[i]-1]);
    print("");
# Out:
# [(4746, 3.824598915817025), (3308, 3.431779787344852), (254, 3.386702300326453), (446, 3.3532708751892946), (3811, 3.238258625206292), (741, 3.2220783148281367), (775, 3.1207632576649935), (1230, 3.1037215490806), (252, 2.994730484667773), (3410, 2.9719088236392643), (2782, 2.9649474825644013), (3088, 2.945863711516469), (3737, 2.8822923338337008), (1932, 2.8088503811638024), (905, 2.79289798666108), (1689, 2.787538481769678), (821, 2.459549478364014), (2051, 2.4538571128018694), (527, 2.452671132829402), (256, 2.4512309720655914), (4333, 2.4480429629955527), (4334, 2.4480429629955527), (4335, 2.4480429629955527), (4336, 2.4480429629955527), (4337, 2.4480429629955527), (4338, 2.4480429629955527), (4339, 2.4480429629955527), (4341, 2.4480429629955527), (868, 2.4436961849896948), (828, 2.4268032044996097), (2160, 2.410475582142933), (1418, 2.3850838197686235), (4509, 2.3793800565170438), (177, 2.3708953583698404), (1981, 2.3487534047043583), (1982, 2.3487534047043583), (1983, 2.3487534
# ...

# %%
print(dataW.loc[4745]);
print("");
print(dataW.loc[3307]);
print("");
print(dataW.loc[253]);
print("");
print(dataW.loc[445]);
print("");
print(dataW.loc[3810]);
# Out:
# fixed_acidity             6.10000
# volatile_acidity          0.26000
# citric_acid               0.25000
# residual_sugar            2.90000
# chlorides                 0.04700
# free_sulfur_dioxide     289.00000
# total_sulfur_dioxide    440.00000
# density                   0.99314
# pH                        3.44000
# sulphates                 0.64000
# alcohol                  10.50000
# quality                   3.00000
# Name: 4745, dtype: float64
#
# fixed_acidity             9.40000
# volatile_acidity          0.24000
# citric_acid               0.29000
# residual_sugar            8.50000
# chlorides                 0.03700
# free_sulfur_dioxide     124.00000
# total_sulfur_dioxide    208.00000
# density                   0.99395
# pH                        2.90000
# sulphates                 0.38000
# alcohol                  11.00000
# quality                   3.00000
# Name: 3307, dtype: float64
#
# fixed_acidity             5.8000
# volatile_acidity          0.2400
# ...
